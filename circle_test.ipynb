# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO("runs/detect/circle_exp/weights/best.pt")
results = model("datasets/images/val/img1.jpg")
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 c:\Users\User\Documents\Java_60\back-end\python-ai\datasets\images\val\img1.jpg: 256x256 1 circle, 850.7ms
# Speed: 178.6ms preprocess, 850.7ms inference, 22.3ms postprocess per image at shape (1, 3, 256, 256)
