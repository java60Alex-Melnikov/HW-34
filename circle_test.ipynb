# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO("runs/detect/train4/weights/best.pt")
results = model("shapes.jpg")
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
